# %%
import pandas as pd
import numpy as np

test_data = pd.read_csv('test.csv')
data = pd.read_csv('train.csv')

test_data
# Out:
#            id     Name  Gender   Age           City  \
# 0      140700   Shivam    Male  53.0  Visakhapatnam
# 1      140701    Sanya  Female  58.0        Kolkata
# 2      140702     Yash    Male  53.0         Jaipur
# 3      140703   Nalini  Female  23.0         Rajkot
# 4      140704  Shaurya    Male  47.0         Kalyan
# ...       ...      ...     ...   ...            ...
# 93795  234495     Zoya  Female  49.0         Jaipur
# 93796  234496    Shlok    Male  29.0      Ahmedabad
# 93797  234497    Rishi    Male  24.0  Visakhapatnam
# 93798  234498   Eshita  Female  23.0         Kalyan
# 93799  234499    Gauri  Female  43.0       Varanasi
#
#       Working Professional or Student              Profession  \
# 0                Working Professional                   Judge
# 1                Working Professional  Educational Consultant
# 2                Working Professional                 Teacher
# 3                             Student                     NaN
# ...

# %% [markdown]
# # **Cleaning data**

# %% [markdown]
# ### Gender mapping

# %%
test_data['Gender'].value_counts()

test_data['Gender'] = test_data['Gender'].map({'Male': 0, 'Female': 1})

# %% [markdown]
# ### Age mapping

# %%
test_data.Age.value_counts()
#All good here
# Out:
# Age
# 56.00    3432
# 49.00    3425
# 38.00    3008
# 53.00    2958
# 57.00    2875
# 47.00    2740
# 46.00    2728
# 18.00    2614
# 59.00    2551
# 54.00    2549
# 51.00    2544
# 43.00    2506
# 48.00    2459
# 20.00    2335
# 45.00    2329
# 50.00    2311
# 24.00    2296
# 42.00    2295
# 28.00    2292
# 39.00    2279
# 44.00    2242
# 29.00    2152
# 41.00    2093
# 33.00    2057
# 58.00    1982
# 25.00    1953
# 40.00    1950
# 35.00    1940
# 21.00    1930
# 55.00    1923
# 23.00    1870
# 37.00    1789
# 34.00    1785
# 36.00    1742
# 19.00    1731
# 27.00    1719
# 60.00    1701
# 52.00    1687
# 31.00    1660
# 22.00    1417
# 26.00    1362
# 30.00    1361
# 32.00    1227
# 32.08       1
# Name: count, dtype: int64

# %% [markdown]
# ### City mapping

# %%
# Using target encoding with cross-validation
from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Create a copy of the city values from the training data
city_values = test_data['City'].copy()

# Create a dictionary to hold the city encoding from the training data
city_encoding = {}

# Fit the KFold on the training data
for train_idx, val_idx in kf.split(data):
    # Calculate the mean depression value for each city in the training set
    city_encoding.update(data.iloc[train_idx].groupby('City')['Depression'].mean().to_dict())

# Map the city encoding to the test data
city_values = test_data['City'].map(city_encoding)

# Assign the encoded values back to the test data
test_data['City'] = city_values

# Fill NaN values with the mean of the depression values from the training data
test_data['City'] = test_data['City'].fillna(data['Depression'].mean())

# %% [markdown]
# ### Working professional or student mapping

# %%
working_mapping = {
    'Student': 0,
    'Working Professional': 1
}
test_data['Working Professional or Student'] = test_data['Working Professional or Student'].map(working_mapping)

# %% [markdown]
# ### Profession mapping

# %%
# Using target encoding with cross-validation
from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Create a copy of the city values from the training data
city_values = test_data['Profession'].copy()

# Create a dictionary to hold the city encoding from the training data
city_encoding = {}

# Fit the KFold on the training data
for train_idx, val_idx in kf.split(data):
    # Calculate the mean depression value for each city in the training set
    city_encoding.update(data.iloc[train_idx].groupby('Profession')['Depression'].mean().to_dict())

# Map the city encoding to the test data
city_values = test_data['Profession'].map(city_encoding)

# Assign the encoded values back to the test data
test_data['Profession'] = city_values

# Fill NaN values with the mean of the depression values from the training data
test_data['Profession'] = test_data['Profession'].fillna(data['Depression'].mean())

# %% [markdown]
# ### Academic pressure mapping

# %%
test_data['Academic Pressure'].value_counts()
#All good here
# Out:
# Academic Pressure
# 3.0    4930
# 5.0    4321
# 4.0    3551
# 1.0    3252
# 2.0    2713
# Name: count, dtype: int64

# %% [markdown]
# ### Work pressure mapping

# %%
test_data['Work Pressure'].value_counts()
#All good here
# Out:
# Work Pressure
# 2.0    16255
# 5.0    15113
# 4.0    14974
# 3.0    14650
# 1.0    14030
# Name: count, dtype: int64

# %% [markdown]
# ### CGPA mapping

# %%
test_data.CGPA.value_counts()
#All good here
# Out:
# CGPA
# 8.04    540
# 5.74    316
# 8.95    272
# 9.96    257
# 9.21    253
#        ...
# 5.50      1
# 9.08      1
# 6.09      1
# 5.92      1
# 5.78      1
# Name: count, Length: 326, dtype: int64

# %% [markdown]
# ### Study Satisfaction mapping

# %%
test_data["Study Satisfaction"].value_counts()
#All good here
# Out:
# Study Satisfaction
# 4.0    4175
# 3.0    3880
# 2.0    3838
# 1.0    3805
# 5.0    3069
# Name: count, dtype: int64

# %% [markdown]
# ### Job Satisfaction mapping

# %%
test_data["Job Satisfaction"].value_counts()
#All good here
# Out:
# Job Satisfaction
# 2.0    16971
# 5.0    14827
# 1.0    14793
# 3.0    14464
# 4.0    13971
# Name: count, dtype: int64

# %% [markdown]
# ### Sleep duration mapping

# %%
#Sleep duration mapping
sleep_mapping = {
    'Less than 5 hours': 4,
    '5-6 hours': 5.5,
    '7-8 hours': 7.5,
    'More than 8 hours': 9
}
test_data['Sleep Duration'] = test_data['Sleep Duration'].map(lambda x: x if x in sleep_mapping.keys() else np.nan)
test_data['Sleep Duration'] = test_data['Sleep Duration'].map(sleep_mapping)
test_data['Sleep Duration'] = test_data['Sleep Duration'].fillna(test_data['Sleep Duration'].median())

# %% [markdown]
# ### Family history of mental illness mapping

# %%
test_data["Family History of Mental Illness"].value_counts()
dict_family_history = {
    'No': 0,
    'Yes': 1
}
test_data["Family History of Mental Illness"] = test_data["Family History of Mental Illness"].map(dict_family_history)
# Korras

# %% [markdown]
# ### Financial stress mapping

# %%
test_data["Financial Stress"].value_counts()
#All good here
# Out:
# Financial Stress
# 2.0    21151
# 5.0    18694
# 4.0    18453
# 1.0    18341
# 3.0    17161
# Name: count, dtype: int64

# %% [markdown]
# ### Work/Study hours mapping

# %%
test_data["Work/Study Hours"].value_counts()
#All good here
# Out:
# Work/Study Hours
# 10.0    9450
# 11.0    8555
# 9.0     8315
# 0.0     8132
# 12.0    7657
# 2.0     7083
# 6.0     7029
# 7.0     6646
# 1.0     6525
# 3.0     6261
# 5.0     6118
# 4.0     6079
# 8.0     5950
# Name: count, dtype: int64

# %% [markdown]
# ### Have you ever had suicidal thoughts mapping

# %%
test_data["Have you ever had suicidal thoughts ?"].value_counts()
dict_suicidal_thoughts = {
    'No': 0,
    'Yes': 1
}
test_data["Have you ever had suicidal thoughts ?"] = test_data["Have you ever had suicidal thoughts ?"].map(dict_suicidal_thoughts)

# %% [markdown]
# ### Degree mapping

# %%
# First calculate target means from training data
target_means = data["Degree"].copy()

# Calculate global mean from training data
global_mean = data['Depression'].mean()  # Add this line

# Apply encoding to test data
test_data_encoded = test_data.copy()
rare_degrees = test_data["Degree"].value_counts()[test_data["Degree"].value_counts() <= 20].index
# Remove rare degrees from test data (same as training)
test_data = test_data[~test_data["Degree"].isin(rare_degrees)]

# Map the degrees using training data means
test_data_encoded['Degree_encoded'] = test_data['Degree'].map(target_means)

# Fill missing values with global mean from training data
test_data_encoded['Degree_encoded'].fillna(global_mean, inplace=True)

# Clean up columns
test_data_encoded.drop('Degree', axis=1, inplace=True)
test_data_encoded = test_data_encoded.rename(columns={'Degree_encoded': 'Degree'})

test_data = test_data_encoded.copy()
# Out:
# /var/folders/1s/n8gj006x063cbj_n6p23fhxc0000gn/T/ipykernel_75986/424805334.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data_encoded['Degree_encoded'].fillna(global_mean, inplace=True)
# ...

# %% [markdown]
# ### Dietary habits mapping

# %%
rare = test_data["Dietary Habits"].value_counts()[test_data["Dietary Habits"].value_counts() <= 20].index

# print(len(data))
test_data = test_data[~test_data["Dietary Habits"].isin(rare)]

# print("Shape before removing rare degrees:", len(data))
# print("\nDietary Habits removed:", list(rare_degrees))
test_data = pd.get_dummies(test_data, columns=['Dietary Habits'])

# %% [markdown]
# # Dropping columns

# %%
test_data.drop(columns=['id'], inplace=True)
test_data.drop(columns=['Name'], inplace=True)

# %% [markdown]
# # Final preprocessed data

# %%
preprocessed_data = test_data.copy()
preprocessed_data.to_csv('preprocessed_test_data.csv', index=False)

# %%
preprocessed_data.head(50)
# Out:
#     Gender   Age      City  Working Professional or Student  Profession  \
# 0        0  53.0  0.164615                                1    0.109318
# 1        1  58.0  0.173027                                1    0.076039
# 2        0  53.0  0.184677                                1    0.057067
# 3        1  23.0  0.169834                                0    0.181713
# 4        0  47.0  0.195089                                1    0.057067
# 5        0  29.0  0.134601                                1    0.044335
# 6        0  47.0  0.164615                                1    0.057067
# 7        1  28.0  0.134601                                1    0.044335
# 8        1  21.0  0.204960                                0    0.181713
# 9        0  21.0  0.184677                                1    0.181713
# 10       0  45.0  0.212892                                1    0.030659
# 11       0  44.0  0.192940                                1    0.019735
# ...
