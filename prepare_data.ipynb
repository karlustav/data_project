# %%
import pandas as pd
import numpy as np

data = pd.read_csv('train.csv')

data
# Out:
#             id      Name  Gender   Age           City  \
# 0            0  Aaradhya  Female  49.0       Ludhiana
# 1            1     Vivan    Male  26.0       Varanasi
# 2            2    Yuvraj    Male  33.0  Visakhapatnam
# 3            3    Yuvraj    Male  22.0         Mumbai
# 4            4      Rhea  Female  30.0         Kanpur
# ...        ...       ...     ...   ...            ...
# 140695  140695     Vidya  Female  18.0      Ahmedabad
# 140696  140696      Lata  Female  41.0      Hyderabad
# 140697  140697   Aanchal  Female  24.0        Kolkata
# 140698  140698    Prachi  Female  49.0       Srinagar
# 140699  140699       Sai    Male  27.0          Patna
#
#        Working Professional or Student         Profession  Academic Pressure  \
# 0                 Working Professional               Chef                NaN
# 1                 Working Professional            Teacher                NaN
# 2                              Student                NaN                5.0
# ...

# %%
labels = data['Depression']
data.drop(columns=['Depression'], inplace=True)
data.drop(columns=['id'], inplace=True)
data.drop(columns=['Name'], inplace=True)
replace_dict = {
    'Gender': {'Male': 0, 'Female': 1},
    'Working Professional or Student': {'Student': 0, 'Working Professional': 1},
    'Academic Pressure': {'No': 0, 'Yes': 1},
    'Work Pressure': {'No': 0, 'Yes': 1},
    'Dietary Habits': {'Healthy': 0, 'Unhealthy': 1},
    'Family History of Mental Illness': {'No': 0, 'Yes': 1}
}

data = data.replace(replace_dict)
prepared_data = pd.concat([data, labels], axis=1)

data
# Out:
# /var/folders/1s/n8gj006x063cbj_n6p23fhxc0000gn/T/ipykernel_49415/4251284203.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace(replace_dict)
#         Gender   Age           City  Working Professional or Student  \
# 0            1  49.0       Ludhiana                                1
# 1            0  26.0       Varanasi                                1
# 2            0  33.0  Visakhapatnam                                0
# 3            0  22.0         Mumbai                                1
# 4            1  30.0         Kanpur                                1
# ...        ...   ...            ...                              ...
# 140695       1  18.0      Ahmedabad                                1
# ...
