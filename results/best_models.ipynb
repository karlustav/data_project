# %%
import pandas as pd
models_df = pd.DataFrame({
    "Models": ["Majority Classifier", "KNN", "Decision Tree", "Random Forest", "Support Vector Machine", "XGBoost", "Tuned Random forest", "Tuned XGBoost", "Winning model", "Neural Networks"],
    "Private Accuracy": [0.81687, 0.92126, 0.89920, 0.93773, 0.93785, 0.93791, 0.93827, 0.93981, 0.94184, 0.93298]
})
models_df = models_df.sort_values("Private Accuracy", ascending=False)

# %%
models_df.head()
# Out:
#                    Models  Private Accuracy
# 8           Winning model           0.94184
# 7           Tuned XGBoost           0.93981
# 6     Tuned Random forest           0.93827
# 5                 XGBoost           0.93791
# 4  Support Vector Machine           0.93785

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(data=models_df, x="Private Accuracy", y="Models")
plt.title("Model Performance (Private Accuracy)")
plt.xlabel("Private Accuracy")
plt.ylabel("Models")
plt.xlim(0.8, 0.95)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=models_df, x="Private Accuracy", y="Models")
plt.title("Model Performance (Private Accuracy)")
plt.xlabel("Private Accuracy")
plt.ylabel("Models")
plt.xlim(0, 1)
plt.show()
